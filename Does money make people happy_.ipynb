# %%
import pandas as pd

# %%
data = pd.read_csv('better life index.csv')

# %%
data
# Out:
#             Country    Employment rate    Long-term unemployment rate  \
# 0         Australia                 72                           1.36
# 1           Austria                 72                           1.94
# 2           Belgium                 62                           3.98
# 3            Canada                 73                           0.81
# 4             Chile                 62                           2.02
# 5    Czech Republic                 72                           1.71
# 6           Denmark                 75                           1.35
# 7           Estonia                 72                           2.13
# 8           Finland                 69                           2.33
# 9            France                 65                           4.33
# 10          Germany                 75                           1.68
# 11           Greece                 52                          16.95
# ...

# %%
data.corr()
# Out:
#                                                Employment rate  \
#   Employment rate                                     1.000000
#   Long-term unemployment rate                        -0.602598
#   Educational attainment                              0.565937
#   Years in education                                  0.323088
#   Air pollution                                      -0.502521
#   Water quality                                       0.821495
#   Voter turnout                                       0.070974
#   Life expectancy                                     0.278683
#   Self-reported health                                0.195835
#   Life satisfaction                                   0.634751
#   Feeling safe walking alone at night                 0.556526
#   Homicide rate                                      -0.209866
#   Employees working very long hours                  -0.229240
#   Time devoted to leisure and personal care           0.231932
# ...

# %%
import matplotlib.pyplot as plt

# %%
x = data['  Life satisfaction']
y = data['GDPperCapita']

# %%
data.columns
# Out:
# Index(['Country', '  Employment rate', '  Long-term unemployment rate',
#        '  Educational attainment', '  Years in education', '  Air pollution',
#        '  Water quality', '  Voter turnout', '  Life expectancy',
#        '  Self-reported health', '  Life satisfaction',
#        '  Feeling safe walking alone at night', '  Homicide rate',
#        '  Employees working very long hours',
#        '  Time devoted to leisure and personal care', 'GDPperCapita'],
#       dtype='object')

# %%
fig, ax = plt.subplots()
fit = np.polyfit(x, y, deg=1)
ax.plot(x, fit[0] * x + fit[1], color='red', )
ax.scatter(x, y)
plt.title('Life Satisfaction vs. GDP per Capita', fontsize=20)

plt.ylabel('GDP per capita')
plt.xlabel('Life Satisfaction')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.show()
# Out:
# /Users/nevinyilmaz/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
fig, ax = plt.subplots()
fit = np.polyfit(x, data['  Employment rate'], deg=1)
ax.plot(x, fit[0] * x + fit[1], color='red', )
ax.scatter(x, data['  Employment rate'] )
plt.title('Life Satisfaction vs. Employment Rate', fontsize=20)

plt.ylabel('Employment Rate')
plt.xlabel('Life Satisfaction')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.show()
# Out:
# /Users/nevinyilmaz/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
fig, ax = plt.subplots()
fit = np.polyfit(x, data['  Air pollution'], deg=1)
ax.plot(x, fit[0] * x + fit[1], color='red', )
ax.scatter(x, data['  Air pollution'] )
plt.title('Life Satisfaction vs. Air Pollution', fontsize=20)

plt.ylabel('Air pollution')
plt.xlabel('Life Satisfaction')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.show()
# Out:
# /Users/nevinyilmaz/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
fig, ax = plt.subplots()
fit = np.polyfit(x, data['  Employees working very long hours'], deg=1)
ax.plot(x, fit[0] * x + fit[1], color='red', )
ax.scatter(x, data['  Employees working very long hours'] )
plt.title('Life Satisfaction vs. Long Hours of Work', fontsize=20)

plt.ylabel('Work hour')
plt.xlabel('Life Satisfaction')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.show()
# Out:
# /Users/nevinyilmaz/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
fig, ax = plt.subplots()
fit = np.polyfit(data['  Homicide rate'], data['  Life expectancy'], deg=1)
ax.plot(data['  Homicide rate'], fit[0] * data['  Homicide rate']+ fit[1], color='red', )
ax.scatter(data['  Homicide rate'], data['  Life expectancy'] )
plt.title('Life Expectancy vs. Homicide Rate', fontsize=20)

plt.ylabel('Life Expectancy')
plt.xlabel('Homicide rate')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.show()
# Out:
# /Users/nevinyilmaz/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
fig, ax = plt.subplots()
fit = np.polyfit(data['  Homicide rate'], data['  Time devoted to leisure and personal care'], deg=1)
ax.plot(data['  Homicide rate'], fit[0] * data['  Homicide rate']+ fit[1], color='red', )
ax.scatter(data['  Homicide rate'], data['  Time devoted to leisure and personal care'] )
plt.title('Homicide Rate vs. Time devoted to leisure and personal care', fontsize=20)

plt.ylabel('Time devoted to leisure and personal care')
plt.xlabel('Homicide rate')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.show()
# Out:
# /Users/nevinyilmaz/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:418: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
data.index = data.Country

# %%
data
# Out:
#                          Country    Employment rate  \
# Country
# Australia              Australia                 72
# Austria                  Austria                 72
# Belgium                  Belgium                 62
# Canada                    Canada                 73
# Chile                      Chile                 62
# Czech Republic    Czech Republic                 72
# Denmark                  Denmark                 75
# Estonia                  Estonia                 72
# Finland                  Finland                 69
# France                    France                 65
# Germany                  Germany                 75
# Greece                    Greece                 52
# Hungary                  Hungary                 67
# Iceland                  Iceland                 86
# Ireland                  Ireland                 65
# Israel                    Israel                 69
# Italy                      Italy                 57
# ...

# %%
params = {'ytick.labelsize':'x-large'}
plt.rcParams.update(params)

# %%
data.sort_values(by='GDPperCapita', inplace=True)
data.plot(y='GDPperCapita', use_index=True, kind='barh', figsize=(30, 20), legend=False)
plt.title('2017 GDP per Capita Comparison by Countries', fontsize=30)
# Out:
# Text(0.5,1,'2017 GDP per Capita Comparison by Countries')
